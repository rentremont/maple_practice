# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
maple_df = pd.read_csv('../../data/Domestic_Maple_Syrup_Production_2000-2021.csv')

# %%
maple_df
# Out:
#              State  Num_of_Taps  Yield_per_Tap Production  Avg_Price   Value  \
# 0            Maine         1960          0.262        514       38.6   19840
# 1         Michigan          550          0.273        150       46.3    6945
# 2    New Hampshire          530          0.240        127       64.9    8242
# 3         New York         2900          0.223        647       37.8   24457
# 4     Pennsylvania          745          0.226        168       36.2    6082
# ..             ...          ...            ...        ...        ...     ...
# 215       New York         1163          0.166        193       29.0   6,090
# 216           Ohio          432          0.222         96       34.3   1,166
# 217   Pennsylvania          360          0.192         69       28.4   1,335
# 218        Vermont         2090          0.132        275       30.0  13,800
# 219      Wisconsin          436          0.156         68       27.7   1,800
#
# ...

# %%
maple_df.isna().sum()
# Out:
# State               0
# Num_of_Taps         0
# Yield_per_Tap       0
# Production          0
# Avg_Price           0
# Value               0
# Retail_Price        0
# Wholesale_Price     0
# Bulk_P_Price        0
# Bulk_G_Price        0
# Date_Open          90
# Date_Closed        90
# Year                0
# dtype: int64

# %%
maple_df.Year.value_counts()
# Out:
# 2018    13
# 2017    13
# 2016    13
# 2010    10
# 2008    10
# 2001    10
# 2002    10
# 2003    10
# 2004    10
# 2005    10
# 2006    10
# 2007    10
# 2000    10
# 2009    10
# 2011    10
# 2012    10
# 2013    10
# 2014    10
# 2015    10
# 2020     7
# 2019     7
# 2021     7
# Name: Year, dtype: int64

# %%
maple_df.Year.value_counts().plot(kind = 'bar');

# %%
maple_df.Num_of_Taps.describe()
# Out:
# count     220.000000
# mean      993.081818
# std      1188.199694
# min        51.000000
# 25%       353.750000
# 50%       470.000000
# 75%      1415.500000
# max      6500.000000
# Name: Num_of_Taps, dtype: float64

# %%
maple_df.Num_of_Taps.hist();

# %%
maple_df.Num_of_Taps.value_counts()
# Out:
# 400     7
# 440     4
# 250     4
# 600     4
# 70      4
#        ..
# 290     1
# 4550    1
# 2310    1
# 310     1
# 436     1
# Name: Num_of_Taps, Length: 144, dtype: int64

# %%
maple_df.Num_of_Taps.hist(bins = 25,
                            color = 'coral',
                            edgecolor = 'black',
                            figsize = (10,6))

plt.title('Distribution of Number of Taps', fontsize = 16);

# %%
maple_df.sort_values(by=['Num_of_Taps'], ascending=False).head(25)
# Out:
#         State  Num_of_Taps  Yield_per_Tap Production  Avg_Price   Value  \
# 5     Vermont         6500          0.269       1750       32.0   56000
# 19    Vermont         6000          0.345       2070       28.0   57960
# 44    Vermont         5900          0.339      2,000       27.0  54,000
# 12    Vermont         5700          0.342       1950       27.0   52650
# 31    Vermont         5670          0.342       1940       28.0   54320
# 57    Vermont         4850          0.410      1,990       30.0  59,700
# 68    Vermont         4550          0.310      1,410       33.0  46,530
# 78    Vermont         4350          0.310      1,350       33.0  44,550
# 88    Vermont         4200          0.352      1,480       33.4  49,432
# 98    Vermont         3500          0.214        750       35.5  26,625
# 108   Vermont         3300          0.345      1,140       35.0  39,900
# 118   Vermont         3150          0.283        890       34.0  30,260
# ...

# %% [markdown]
# ## Vermont has the highest number of taps. Top 13 spots. 2009-2021

# %%
maple_df.State.value_counts()
# Out:
# Maine            22
# Michigan         22
# New Hampshire    22
# New York         22
# Pennsylvania     22
# Vermont          22
# Wisconsin        22
# Connecticut      19
# Massachusetts    19
# Ohio             19
# Indiana           3
# Minnesota         3
# West Virginia     3
# Name: State, dtype: int64

# %%
maple_df.sort_values(by=['Yield_per_Tap'], ascending=False).head(25)
# Out:
#              State  Num_of_Taps  Yield_per_Tap Production  Avg_Price   Value  \
# 57         Vermont         4850          0.410      1,990       30.0  59,700
# 6        Wisconsin          900          0.406        365       33.1   12082
# 36           Maine         1900          0.376        715       33.7  24,096
# 49           Maine         1860          0.363        675       30.0  20,250
# 89       Wisconsin          740          0.358        265       37.4   9,911
# 86            Ohio          440          0.352        155       36.9   5,720
# 88         Vermont         4200          0.352      1,480       33.4  49,432
# 108        Vermont         3300          0.345      1,140       35.0  39,900
# 19         Vermont         6000          0.345       2070       28.0   57960
# 12         Vermont         5700          0.342       1950       27.0   52650
# 31         Vermont         5670          0.342       1940       28.0   54320
# ...

# %% [markdown]
# ## Vermont also has the highest yield per tap.

# %%
maple_df.sort_values(by=['Production'], ascending=False).head(25)
# Out:
#              State  Num_of_Taps  Yield_per_Tap Production  Avg_Price   Value  \
# 97    Pennsylvania          501          0.192         96       39.4   3,782
# 216           Ohio          432          0.222         96       34.3   1,166
# 134  New Hampshire          395          0.241         95       53.8   5,111
# 149      Wisconsin          600          0.158         95       35.7   3,392
# 124  New Hampshire          385          0.244         94       53.5   5,029
# 128        Vermont         3030          0.304        920       35.1  32,292
# 127   Pennsylvania          464          0.198         92       38.1   3,505
# 29            Ohio          400          0.225         90       45.4    4086
# 126           Ohio          375          0.240         90       40.3   3,627
# 51        Michigan          400          0.225         90       44.8   4,032
# 110    Connecticut           75          0.120          9       70.0     630
# ...

# %%
maple_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   State            220 non-null    object
#  1   Num_of_Taps      220 non-null    int64
#  2   Yield_per_Tap    220 non-null    float64
#  3   Production       220 non-null    object
#  4   Avg_Price        220 non-null    float64
#  5   Value            220 non-null    object
#  6   Retail_Price     220 non-null    float64
#  7   Wholesale_Price  220 non-null    object
#  8   Bulk_P_Price     220 non-null    object
#  9   Bulk_G_Price     220 non-null    object
#  10  Date_Open        130 non-null    object
#  11  Date_Closed      130 non-null    object
#  12  Year             220 non-null    int64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 22.5+ KB

# %% [markdown]
# maple_df['Wholesale_Price']=maple_df['Wholesale_Price'].astype(float)

# %%
maple_df.Wholesale_Price.describe()
# Out:
# count     220
# unique    158
# top       (D)
# freq        6
# Name: Wholesale_Price, dtype: object

# %%
maple_df.loc[maple_df['Wholesale_Price'] == '(D)']
# Out:
#              State  Num_of_Taps  Yield_per_Tap Production  Avg_Price   Value  \
# 32   West Virginia           66          0.121          8       44.6     357
# 34     Connecticut           78          0.231         18       62.2   1,120
# 58   West Virginia           51          0.118          6       48.4     290
# 81           Maine         1880          0.298        560       32.0  17,920
# 100    Connecticut           71          0.239         17       73.0   1,241
# 210    Connecticut           51          0.176          9       43.9     307
#
#      Retail_Price Wholesale_Price Bulk_P_Price Bulk_G_Price  Date_Open  \
# 32           53.9             (D)         2.90        32.20  1/19/2018
# 34           51.6             (D)          (D)          (D)  1/20/2017
# 58           43.7             (D)          2.8         30.3   1/1/2016
# 81           55.1             (D)          2.8         30.9   2/4/2013
# 100          57.0             (D)          (D)          (D)  1/22/2011
# ...

# %%
maple_dfwholesale=maple_df.loc[maple_df['Wholesale_Price'] != '(D)']
maple_dfwholesale
# Out:
#              State  Num_of_Taps  Yield_per_Tap Production  Avg_Price   Value  \
# 0            Maine         1960          0.262        514       38.6   19840
# 1         Michigan          550          0.273        150       46.3    6945
# 2    New Hampshire          530          0.240        127       64.9    8242
# 3         New York         2900          0.223        647       37.8   24457
# 4     Pennsylvania          745          0.226        168       36.2    6082
# ..             ...          ...            ...        ...        ...     ...
# 215       New York         1163          0.166        193       29.0   6,090
# 216           Ohio          432          0.222         96       34.3   1,166
# 217   Pennsylvania          360          0.192         69       28.4   1,335
# 218        Vermont         2090          0.132        275       30.0  13,800
# 219      Wisconsin          436          0.156         68       27.7   1,800
#
# ...

# %%
maple_dfwholesale['Wholesale_Price']=maple_dfwholesale['Wholesale_Price'].astype(float)
# Out:
# C:\Users\neyan\AppData\Local\Temp\ipykernel_35508\3799378726.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   maple_dfwholesale['Wholesale_Price']=maple_dfwholesale['Wholesale_Price'].astype(float)

# %%
maple_dfwholesale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 214 entries, 0 to 219
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   State            214 non-null    object
#  1   Num_of_Taps      214 non-null    int64
#  2   Yield_per_Tap    214 non-null    float64
#  3   Production       214 non-null    object
#  4   Avg_Price        214 non-null    float64
#  5   Value            214 non-null    object
#  6   Retail_Price     214 non-null    float64
#  7   Wholesale_Price  214 non-null    float64
#  8   Bulk_P_Price     214 non-null    object
#  9   Bulk_G_Price     214 non-null    object
#  10  Date_Open        125 non-null    object
#  11  Date_Closed      125 non-null    object
#  12  Year             214 non-null    int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 23.4+ KB

# %%
maple_dfwholesale.sort_values(by=['Wholesale_Price'], ascending=False).head(10)
# Out:
#              State  Num_of_Taps  Yield_per_Tap Production  Avg_Price  Value  \
# 9    New Hampshire          530          0.291        154       52.1   8023
# 7            Maine         1970          0.299        590       34.9  20591
# 60     Connecticut           85          0.224         19       87.2  1,657
# 110    Connecticut           75          0.120          9       70.0    630
# 90     Connecticut           70          0.157         11       63.4    697
# 47     Connecticut           85          0.224         19       69.5  1,321
# 80     Connecticut           78          0.256         20       71.0  1,420
# 21     Connecticut           73          0.247         18       76.0   1368
# 45   West Virginia           70          0.157         11       36.7    404
# 70     Connecticut           83          0.193         16       70.9  1,134
#
#      Retail_Price  Wholesale_Price Bulk_P_Price Bulk_G_Price  Date_Open  \
# ...

# %% [markdown]
# ## New Hampshire in 2020 has the highest wholesale price of 65.5. Connecticut has 7 of the top 10 spots for highest wholesale price.

# %%
maple_dfwholesale.Wholesale_Price.sort_values(ascending=False).head(10).plot(kind = 'bar');
